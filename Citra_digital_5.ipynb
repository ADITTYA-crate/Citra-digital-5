# %% [markdown]
# <a href="https://colab.research.google.com/github/ADITTYA-crate/Citra-digital-5/blob/main/Citra_digital_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT LIBRARY
import cv2
import numpy as np
import matplotlib.pyplot as plt

# UPLOAD GAMBAR
from google.colab import files
uploaded = files.upload()

# LOAD IMAGE
img = cv2.imread(list(uploaded.keys())[0])
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# =========================
# LOW PASS FILTER (LPF)
# =========================
lpf = cv2.GaussianBlur(img, (5,5), 0)

# =========================
# HIGH PASS FILTER (HPF)
# =========================
kernel_hpf = np.array([[-1,-1,-1],
                       [-1, 8,-1],
                       [-1,-1,-1]])
hpf = cv2.filter2D(img, -1, kernel_hpf)

# =========================
# BAND PASS FILTER (BPF)
# =========================
low = cv2.GaussianBlur(img, (9,9), 0)
band = cv2.subtract(img, low)

# =========================
# TAMPILKAN HASIL
# =========================
plt.figure(figsize=(10,6))

plt.subplot(2,2,1)
plt.title("Original")
plt.imshow(img, cmap='gray')

plt.subplot(2,2,2)
plt.title("Low Pass")
plt.imshow(lpf, cmap='gray')

plt.subplot(2,2,3)
plt.title("High Pass")
plt.imshow(hpf, cmap='gray')

plt.subplot(2,2,4)
plt.title("Band Pass")
plt.imshow(band, cmap='gray')

plt.show()
# Out:
#      <input type="file" id="files-67575812-6481-41e5-85e2-c2bd75da8e77" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67575812-6481-41e5-85e2-c2bd75da8e77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
